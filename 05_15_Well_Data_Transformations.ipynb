# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/TableExportforExcel.csv"

# %%
df = pd.read_csv(path)

df
# Out:
#        FID    API_Number  County_Cod County_Nam  Pmt_Number  \
# 0        0  4.708704e+09        87.0      Roane      4303.0
# 1        2  4.700502e+09         5.0      Boone      1831.0
# 2        3  4.709502e+09        95.0      Tyler      1760.0
# 3        4  4.709502e+09        95.0      Tyler      1775.0
# 4        5  4.704502e+09        45.0      Logan      1644.0
# ...    ...           ...         ...        ...         ...
# 2286  3127  4.700502e+09         5.0      Boone      2147.0
# 2287  3128  4.700502e+09         5.0      Boone      2195.0
# 2288  3129  4.703306e+09        33.0   Harrison      5619.0
# 2289  3130  4.704502e+09        45.0      Logan      1827.0
# 2290  3131  4.708510e+09        85.0    Ritchie      9996.0
#
#                           Suffix     Status  Pmt_Issued  \
# 0              Original Location  Completed  11/14/2001
# 1              Original Location  Completed  10/10/2002
# 2              Original Location  Completed  11/26/2003
# ...

# %%
df.columns
# Out:
# Index(['FID', 'API_Number', 'County_Cod', 'County_Nam', 'Pmt_Number', 'Suffix',
#        'Status', 'Pmt_Issued', 'Operator_a', 'Surface_Ow', 'Mineral_Ow',
#        'Company_Nu', 'Well_Numbe', 'Quad_Name', 'UTME', 'UTMN', 'Longitude',
#        'Latitude', 'Datum', 'Deepest_Ta', 'Target_Fm_', 'Target_Fm1',
#        'Target_F_1', 'Spud_Date', 'Completion', 'TVD_Cmpl_R', 'TMD_Cmpl_R',
#        'Gas_IOF', 'Gas_FOF', 'Oil_IOF', 'Oil_FOF', 'Rock_Press', 'Deepest_Fm',
#        'Deepest__1', 'Well_Type', 'F2005_Gas_', 'F2006_Gas_', 'F2007_Gas_',
#        'F2008_Gas_', 'F2009_Gas_', 'F2010_Gas_', 'F2011_Gas_', 'F2012_Gas_',
#        'F2013_Gas_', 'F2014_Gas_', 'F2015_Gas_', 'F2015_gas', 'Rock_Pres',
#        'gas_flow', 'Decline'],
#       dtype='object')

# %%
df2 = df[ (df['F2005_Gas_'] > 0) |  (df['F2006_Gas_'] > 0) ]

df2
# Out:
#        FID    API_Number  County_Cod County_Nam  Pmt_Number  \
# 0        0  4.708704e+09        87.0      Roane      4303.0
# 1        2  4.700502e+09         5.0      Boone      1831.0
# 2        3  4.709502e+09        95.0      Tyler      1760.0
# 3        4  4.709502e+09        95.0      Tyler      1775.0
# 4        5  4.704502e+09        45.0      Logan      1644.0
# ...    ...           ...         ...        ...         ...
# 1226  1237  4.701302e+09        13.0    Calhoun      1511.0
# 1272  1283  4.703503e+09        35.0    Jackson      2639.0
# 1337  1348  4.705901e+09        59.0      Mingo      1202.0
# 1422  1433  4.707700e+09        77.0    Preston       102.0
# 2289  3130  4.704502e+09        45.0      Logan      1827.0
#
#                  Suffix     Status  Pmt_Issued                     Operator_a  \
# 0     Original Location  Completed  11/14/2001                    Key Oil Co.
# 1     Original Location  Completed  10/10/2002  Eastern American Energy Corp.
# ...

# %%
df3 = df2['F2015_gas']

df3.replace(0,1)
# Out:
# 0        2922
# 1        3367
# 2           1
# 3           1
# 4        7466
#         ...
# 1226      559
# 1272     7419
# 1337    10903
# 1422       59
# 2289    12224
# Name: F2015_gas, Length: 359, dtype: int64

# %%
df2['F2015_gas'] = df2['F2015_gas'].replace(0,1)

df2
# Out:
# <ipython-input-48-1cd79ba5e4c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['F2015_gas'] = df2['F2015_gas'].replace(0,1)
#        FID    API_Number  County_Cod County_Nam  Pmt_Number  \
# 0        0  4.708704e+09        87.0      Roane      4303.0
# 1        2  4.700502e+09         5.0      Boone      1831.0
# 2        3  4.709502e+09        95.0      Tyler      1760.0
# 3        4  4.709502e+09        95.0      Tyler      1775.0
# 4        5  4.704502e+09        45.0      Logan      1644.0
# ...    ...           ...         ...        ...         ...
# 1226  1237  4.701302e+09        13.0    Calhoun      1511.0
# 1272  1283  4.703503e+09        35.0    Jackson      2639.0
# ...

# %%
df2["Prod_Dec"] = 1 - df2["F2015_gas"] / df2["F2005_Gas_"]
# Out:
# <ipython-input-55-65787f22b4cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Prod_Dec"] = 1 - df2["F2015_gas"] / df2["F2005_Gas_"]

# %%
a = df2.index[df2['Prod_Dec'] < 0]

a
# Out:
# Int64Index([   1,    4,   11,   18,   19,   23,   33,   36,   38,   40,
#             ...
#              737,  833,  855,  869,  912,  983, 1099, 1272, 1337, 2289],
#            dtype='int64', length=305)

# %%
df2.loc[a, "Prod_Dec"] = 1 - df2["F2015_gas"] / df2["F2006_Gas_"]

# %%
df2
# Out:
#        FID    API_Number  County_Cod County_Nam  Pmt_Number  \
# 0        0  4.708704e+09        87.0      Roane      4303.0
# 1        2  4.700502e+09         5.0      Boone      1831.0
# 2        3  4.709502e+09        95.0      Tyler      1760.0
# 3        4  4.709502e+09        95.0      Tyler      1775.0
# 4        5  4.704502e+09        45.0      Logan      1644.0
# ...    ...           ...         ...        ...         ...
# 1226  1237  4.701302e+09        13.0    Calhoun      1511.0
# 1272  1283  4.703503e+09        35.0    Jackson      2639.0
# 1337  1348  4.705901e+09        59.0      Mingo      1202.0
# 1422  1433  4.707700e+09        77.0    Preston       102.0
# 2289  3130  4.704502e+09        45.0      Logan      1827.0
#
#                  Suffix     Status  Pmt_Issued                     Operator_a  \
# 0     Original Location  Completed  11/14/2001                    Key Oil Co.
# 1     Original Location  Completed  10/10/2002  Eastern American Energy Corp.
# ...

# %%
df3 = df2[df2.Prod_Dec != "-inf"]

df3

# %%
df2.to_csv('WellDecline.csv')

# %%
df2.to_csv('/content/drive/MyDrive/WellDecline.csv')
